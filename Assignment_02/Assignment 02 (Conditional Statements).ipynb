# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
service = int(input("Enter years of service: "))

if service > 5:
    salary = int(input("Enter your salary: "))
    print(f"Your net bonus is: {salary * 0.05}")
else:
    print("You are not eligible for bonus")
# Out:
# Your net bonus is: 4000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age: "))

if age > 17:
    print("You are eligible for voting")
else:
    print("You are not eligible for voting")
# Out:
# You are eligible for voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num_1 = int(input("Enter any number: "))

if num_1 % 2 == 0:
    print("Even number")
else: 
    print("Odd number")
# Out:
# Odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num_2 = int(input("Enter any number: "))
if num_2 % 7 == 0:
    print("Number is divisible by 7")
else:
    print("Number is'nt divisible by 7")
# Out:
# Number is'nt divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num_3 = int(input("Enter any number: "))
if num_3 % 5 == 0:
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
units = float(input("Enter the number of units you have consumed: "))

if units <= 100:
    bill = units * 0
elif units <= 200:
    bill = units * 5.0
else:
    bill = units * 10.0

print("Your total bill is: ", bill)
# Out:
# Your total bill is:  625.0

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
num_4 = int(input("Enter a number: "))
last_digit = num_4 % 10
print("The last digit is:", last_digit)
# Out:
# The last digit is: 2

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter the length in meters: "))
breadth = int(input("Enter the bredth in meters: "))

if length == breadth:
    print("Square")
else:
    print("Rectangle")
# Out:
# Rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num_5 = int(input("Enter any number: "))
num_6 = int(input("Enter any number: "))

if num_5 > num_6:
    print(num_5)
elif num_6 > num_5:
    print(num_6)
else:
    print()
# Out:
# 56

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
quantity = int(input("Enter quantity of units you have purchased"))
cost = 100
final_cost = quantity * cost

if quantity > 1000: 
    print(f"The total cost is {final_cost * (1 - 0.1)} after 10% discount")
else:
    print(f"The total cost is {final_cost}")
# Out:
# The total cost is 450000.0 after 10% discount

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter your marks: "))

if marks > 80:
    print("Grade A")
elif marks > 60 and marks < 80:
    print("Grade B")
elif marks > 50 and marks < 60:
    print("Grade C")
elif marks > 50 and marks < 60:
    print("Grade C")
elif marks > 45 and marks < 50:
    print("Grade D")
elif marks > 25 and marks < 45:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Grade B

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age_1 = int(input("Enter age of first person: "))
age_2 = int(input("Enter age of second person: "))
age_3 = int(input("Enter age of third person: "))

if age_1 > age_2 and age_1 > age_3:
    print("First person is the oldest.")
elif age_2 > age_1 and age_2 > age_3:
    print("Second person is the oldest.")
elif age_3 > age_1 and age_3 > age_2:
    print("Third person is the oldest.")
else:
    print("There is no clear oldest person.")
# Out:
# Third person is the oldest.

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# Number of classes held
#
# Number of classes attended.
#
# And print
#
# percentage of class attended
#
# Is student is allowed to sit in exam or not.

# %%
classes_held = int(input("Enter number of classes held: "))
classes_attend = int(input("Enter the classes yoy have attend: "))
percentage = (classes_attend / classes_held) * 100

if percentage >= 75:
    print(f"Attendance Percentage: {percentage}\nYou are allowed to sit in exams")
else: 
    print(f"Attendance Percentage: {percentage}\nYou are not allowed to sit in exams")
# Out:
# Attendance Percentage: 52.083333333333336
# You are not allowed to sit in exams

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
classes_held = int(input("Enter number of classes held: "))
classes_attend = int(input("Enter the classes yoy have attend: "))
percentage = (classes_attend / classes_held) * 100

if percentage >= 75:
    print(f"Attendance Percentage: {percentage}\nYou are allowed to sit in exams")
else:
    med_cause = str(input("Enter if you have any medical problem (Y/N): "))
    if percentage < 75 and med_cause == 'Y': 
        print(f"Attendance Percentage: {percentage}\nYou are allowed to sit in exams because of medical condition")
    else: 
        print(f"Attendance Percentage: {percentage}\nYou are not allowed to sit in exams")
# Out:
# Attendance Percentage: 62.5
# You are allowed to sit in exams because of medical condition

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter any year to check if it is a leap year: "))

if year %  4 == 0 or year % 400 == 0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2020 is a leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Age: "))
gender = str (input("Gender (M/F): "))
marital_status = str(input("Marital status (Y/N): "))

if gender == 'F':
    print("You can only work in Urban areas")
elif gender == 'M' and  40 <= age <= 60:
    print("You will work only in urban areas")
elif gender == 'M' and age > 20 < 40:
    print("You may work anywhere")
else:
    print("Error")
# Out:
# You will work only in urban areas
